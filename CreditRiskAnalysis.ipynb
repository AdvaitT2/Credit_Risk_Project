# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

#plotting libraries
import matplotlib.pyplot as plt
# %matplotlib inline #to enabloe plotting graphs in jupyter

import seaborn as sns #for statistical plots

import numpy as np
# Out:
# UsageError: unrecognized arguments: #to enabloe plotting graphs in jupyter

# %%
crdf = pd.read_csv(r"CreditRisk.csv")
crdf.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0           0             360.0
# 1             4583             1508.0         128             360.0
# 2             3000                0.0          66             360.0
# 3             2583             2358.0         120             360.0
# 4             6000                0.0         141             360.0
#
#    Credit_History Property_Area  Loan_Status
# 0             1.0         Urban            1
# 1             1.0         Rural            0
# ...

# %%
print(crdf.shape) #number of rows and columns in the dataframe
crdf.describe(include='object') #table of information about the dataframe
# Out:
# (614, 13)
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002990   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area
# count            614
# unique             3
# top        Semiurban
# freq             233

# %%
print(crdf.info) #information about the dataframe, null values etc
# Out:
# <bound method DataFrame.info of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
crdf.describe().T #the .T flips over the axis
# Out:
#                    count         mean          std    min     25%     50%  \
# ApplicantIncome    614.0  5403.459283  6109.041673  150.0  2877.5  3812.5
# CoapplicantIncome  614.0  1621.245798  2926.248369    0.0     0.0  1188.5
# LoanAmount         614.0   141.166124    88.340630    0.0    98.0   125.0
# Loan_Amount_Term   600.0   342.000000    65.120410   12.0   360.0   360.0
# Credit_History     564.0     0.842199     0.364878    0.0     1.0     1.0
# Loan_Status        614.0     0.687296     0.463973    0.0     0.0     1.0
#
#                        75%      max
# ApplicantIncome    5795.00  81000.0
# CoapplicantIncome  2297.25  41667.0
# LoanAmount          164.75    700.0
# Loan_Amount_Term    360.00    480.0
# Credit_History        1.00      1.0
# Loan_Status           1.00      1.0

# %%
crdf
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
cr_df = crdf.drop('Loan_ID', axis = 1)
cr_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0           0             360.0             1.0
# 1             1508.0         128             360.0             1.0
# 2                0.0          66             360.0             1.0
# 3             2358.0         120             360.0             1.0
# 4                0.0         141             360.0             1.0
#
#   Property_Area  Loan_Status
# 0         Urban            1
# 1         Rural            0
# 2         Urban            1
# ...

# %%
numeric_columns = cr_df.select_dtypes(include=[np.number]).columns.tolist
numeric_columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 numeric_columns = cr_df.select_dtypes(include=[np.number]).columns.tolist
#       2 numeric_columns
#
# NameError: name 'np' is not defined

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

for i in ['ApplicantIncome','CoapplicantIncome','LoanAmount']:
    sns.displot(crdf[i], kde = [True])
    plt.show()

# %%
#converting the data type of loan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.nunique()
#
# NameError: name 'df' is not defined

# %%
#converting the data type of loan status and credit history to category
cr_df['Loan_Status'] = cr_df['Loan_Status'].astype('category')
cr_df['Credit_History'] = cr_df['Credit_History'].astype('category')

# %%
for i in list(cr_df.columns[cr_df.dtypes=='object']):
    print(cr_df[i].value_counts(normalize=True)*100 )
    print()
# Out:
# Gender
# Male      81.364393
# Female    18.635607
# Name: proportion, dtype: float64
#
# Married
# Yes    65.139116
# No     34.860884
# Name: proportion, dtype: float64
#
# Dependents
# 0     57.595993
# 1     17.028381
# 2     16.861436
# 3+     8.514190
# Name: proportion, dtype: float64
#
# Education
# Graduate        78.175896
# Not Graduate    21.824104
# Name: proportion, dtype: float64
#
# Self_Employed
# No     85.910653
# Yes    14.089347
# Name: proportion, dtype: float64
#
# Property_Area
# Semiurban    37.947883
# Urban        32.899023
# Rural        29.153094
# Name: proportion, dtype: float64

# %%
crdf.groupby(['Loan_Status','Gender','Property_Area'])['Married'].value_counts()
# Out:
# Loan_Status  Gender  Property_Area  Married
# 0            Female  Rural          No           7
#                                     Yes          3
#                      Semiurban      No          12
#                                     Yes          1
#                      Urban          No          10
#                                     Yes          4
#              Male    Rural          Yes         39
#                                     No          18
#                      Semiurban      Yes         27
#                                     No          12
#                      Urban          Yes         35
#                                     No          19
# 1            Female  Rural          No          12
#                                     Yes          2
#                      Semiurban      No          22
#                                     Yes         19
#                      Urban          No          17
#                                     Yes          2
# ...

# %%
cr_df[cr_df['Married'].isnull()]
# Out:
#      Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 104    Male     NaN        NaN  Graduate            No             3816
# 228    Male     NaN        NaN  Graduate            No             4758
# 435  Female     NaN        NaN  Graduate            No            10047
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 104              754.0         160             360.0             1.0
# 228                0.0         158             480.0             1.0
# 435                0.0           0             240.0             1.0
#
#     Property_Area  Loan_Status
# 104         Urban            1
# 228     Semiurban            1
# 435     Semiurban            1

# %%
cr_df.loc[104,'Married'] = 'Yes'
cr_df.loc[228,'Married'] = 'Yes'
cr_df.loc[435,'Married'] = 'Yes'

# %%
cr_df.isnull().sum()
# Out:
# Gender               13
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Filling null values in gender whose CoapplicantIncome is 0 with female

z = cr_df[cr_df['CoapplicantIncome'] == 0]

for i in list(z[z['Gender'].isnull()].index):
    # this would give row numbers of places where gender is null and have CoapplicantIncome as @
    cr_df.loc[i,'Gender' ] = 'Female'

# %%
#filling Null Values

cr_df['Credit_History'].fillna('e',inplace=True)

cr_df['Self_Employed'].fillna('No',inplace=True) #replacing with mode

cr_df['Dependents'].fillna('e',inplace=True) #replacing with mode

# %%
cr_df['Gender'].fillna('Male',inplace = True)

# %%
cr_df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr_df.groupby(['Loan_Status']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tripa\Documents\Advait\PYTHON\envs\CRPenv\lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\tripa\Documents\Advait\PYTHON\envs\CRPenv\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\tripa\Documents\Advait\PYTHON\envs\CRPenv\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...
